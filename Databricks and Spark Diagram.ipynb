# %% [markdown]
# <a href="https://colab.research.google.com/github/aswinaus/ML/blob/main/Databricks%20and%20Spark%20Diagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create the diagram
fig, ax = plt.subplots(figsize=(14, 8))
ax.axis('off')

# Databricks Layer
ax.add_patch(patches.Rectangle((0.1, 0.7), 0.8, 0.25, edgecolor='black', facecolor='#f3f3f3'))
ax.text(0.5, 0.89, 'Databricks Platform', ha='center', va='center', fontsize=14, fontweight='bold')

# Databricks Components
ax.add_patch(patches.Rectangle((0.12, 0.73), 0.22, 0.18, edgecolor='black', facecolor='#d5e8d4'))
ax.text(0.23, 0.82, 'Notebooks\n(PySpark, SQL, Scala)', ha='center', va='center', fontsize=11)

ax.add_patch(patches.Rectangle((0.38, 0.73), 0.22, 0.18, edgecolor='black', facecolor='#fff2cc'))
ax.text(0.49, 0.82, 'Delta Lake\n(ACID Storage)', ha='center', va='center', fontsize=11)

ax.add_patch(patches.Rectangle((0.64, 0.73), 0.22, 0.18, edgecolor='black', facecolor='#dae8fc'))
ax.text(0.75, 0.82, 'Job Scheduler\n& MLflow', ha='center', va='center', fontsize=11)

# Spark Layer
ax.add_patch(patches.Rectangle((0.1, 0.4), 0.8, 0.25, edgecolor='black', facecolor='#f3f3f3'))
ax.text(0.5, 0.63, 'Apache Spark Engine', ha='center', va='center', fontsize=14, fontweight='bold')

# Spark Components
ax.add_patch(patches.Rectangle((0.12, 0.43), 0.18, 0.18, edgecolor='black', facecolor='#e1d5e7'))
ax.text(0.21, 0.52, 'Spark Core', ha='center', va='center', fontsize=11)

ax.add_patch(patches.Rectangle((0.32, 0.43), 0.18, 0.18, edgecolor='black', facecolor='#e1d5e7'))
ax.text(0.41, 0.52, 'Spark SQL', ha='center', va='center', fontsize=11)

ax.add_patch(patches.Rectangle((0.52, 0.43), 0.18, 0.18, edgecolor='black', facecolor='#e1d5e7'))
ax.text(0.61, 0.52, 'Spark MLlib', ha='center', va='center', fontsize=11)

ax.add_patch(patches.Rectangle((0.72, 0.43), 0.18, 0.18, edgecolor='black', facecolor='#e1d5e7'))
ax.text(0.81, 0.52, 'Spark Streaming', ha='center', va='center', fontsize=11)

# Infrastructure Layer
ax.add_patch(patches.Rectangle((0.1, 0.1), 0.8, 0.22, edgecolor='black', facecolor='#f3f3f3'))
